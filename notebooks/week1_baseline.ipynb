# %% [markdown]
# # Pekan 1 - Log Clustering Baseline
#
# Notebook ringkas ini memakai pipeline yang sama dengan CLI `python -m log_clustering.week1`.

# %% [markdown]
# Dataset: Zenodo `scenario-1`, DOI `10.5281/zenodo.15493424`. Letakkan `timeline.csv` di root repository sebelum menjalankan cell pipeline.

# %%
from pathlib import Path
import sys
import pandas as pd

PROJECT_ROOT = Path.cwd().parent if Path.cwd().name == "notebooks" else Path.cwd()
if str(PROJECT_ROOT) not in sys.path:
    sys.path.insert(0, str(PROJECT_ROOT))

from log_clustering.week1 import run_week1

# %%
result = run_week1(
    input_path=PROJECT_ROOT / "timeline.csv",
    output_dir=PROJECT_ROOT / "reports/week1",
    sample_size=100_000,
    seed=42,
    k_values=[10, 20, 50],
)
result["metrics"]
# Out:
#    sample_size  seed   k  tfidf_features  svd_components  silhouette  \
# 0       100000    42  10            5000              50    0.610530
# 1       100000    42  20            5000              50    0.643834
# 2       100000    42  50            5000              50    0.732457
#
#    calinski_harabasz  davies_bouldin       inertia  embedding_time_s  \
# 0       26164.244151        1.349188  22887.266949             1.378
# 1       25298.431714        1.273936  13221.700310             1.378
# 2       27389.339238        0.889775   5322.282585             1.378
#
#    clustering_time_s
# 0              0.621
# 1              0.987
# 2              2.518

# %%
pd.read_csv(PROJECT_ROOT / "reports/week1/cluster_summary_week1.csv").head(10)
# Out:
#     k  cluster_id   size                                          top_terms  \
# 0  10           0   6200  studio; path_token visual; visual studio; stud...
# 1  10           1  23859  source_file path_token; source_file; path_toke...
# 2  10           2  16567  num_token; reference num_token; update; refere...
# 3  10           3  12310  source_reg hkey_local_machine; hkey_local_mach...
# 4  10           4  14494  num_token; num_token num_token; reg_dword_le; ...
# 5  10           5   2902  kits; path_token kits; kits path_token; path_t...
# 6  10           6   3775  path_token path_token; path_token; source_file...
# 7  10           7   6986  path_token directory; directory; source_file p...
# 8  10           8   7752  sdks path_token; sdks; path_token sdks; path_t...
# 9  10           9   5155  num_token; num_token componentfamilies; compon...
#
#                                          top_sources  \
# 0                          FILE:6069; REG:129; LNK:2
# ...
