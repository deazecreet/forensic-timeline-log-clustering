# %% [markdown]
# # Pekan 1 - Log Clustering Baseline
#
# Notebook ringkas ini memakai pipeline yang sama dengan CLI `python -m log_clustering.week1`.

# %% [markdown]
# Dataset: Zenodo `scenario-1`, DOI `10.5281/zenodo.15493424`. Letakkan `timeline.csv` di root repository sebelum menjalankan cell pipeline.

# %%
from pathlib import Path
import sys
import pandas as pd

PROJECT_ROOT = Path.cwd().parent if Path.cwd().name == "notebooks" else Path.cwd()
if str(PROJECT_ROOT) not in sys.path:
    sys.path.insert(0, str(PROJECT_ROOT))

from log_clustering.week1 import run_week1

# %%
result = run_week1(
    input_path=PROJECT_ROOT / "timeline.csv",
    output_dir=PROJECT_ROOT / "reports/week1",
    sample_size=50_000,
    seed=42,
    k_values=[10, 20, 50],
)
result["metrics"]
# Out:
#    sample_size  seed   k  tfidf_features  svd_components  silhouette  \
# 0        50000    42  10            5000              50    0.567965
# 1        50000    42  20            5000              50    0.632736
# 2        50000    42  50            5000              50    0.728759
#
#    calinski_harabasz  davies_bouldin       inertia  embedding_time_s  \
# 0       12159.759006        1.388500  12021.058901             0.779
# 1       12149.445840        1.402737   6823.273208             0.779
# 2       13417.249718        0.801051   2707.055052             0.779
#
#    clustering_time_s
# 0              0.409
# 1              0.547
# 2              1.361

# %%
pd.read_csv(PROJECT_ROOT / "reports/week1/cluster_summary_week1.csv").head(10)
# Out:
#     k  cluster_id   size                                          top_terms  \
# 0  10           0   3586  path_token directory; directory; source_file p...
# 1  10           1   8248  num_token; update; num_token num_token; update...
# 2  10           2   5086  path_token path_token; path_token; source_file...
# 3  10           3   6197  num_token; num_token num_token; reg_dword_le; ...
# 4  10           4  11807  source_file path_token; source_file; path_toke...
# 5  10           5   6438  source_reg hkey_local_machine; hkey_local_mach...
# 6  10           6   2629  num_token; num_token componentfamilies; compon...
# 7  10           7    747  dll; source_pe; source_pe pe; pe; dynamic link...
# 8  10           8   3761  sdks path_token; path_token sdks; sdks; path_t...
# 9  10           9   1501  path_token kits; kits path_token; kits; path_t...
#
#                                          top_sources  \
# 0                                          FILE:3586
# 1                                          FILE:8248
# 2         FILE:5031; REG:47; EVT:4; LNK:3; AMCACHE:1
# 3  REG:4063; EVT:1366; FILE:667; WEBHIST:40; OLEC...
# 4                                         FILE:11807
# 5                                           REG:6438
# 6                                           REG:2629
# 7                                             PE:747
# 8                                  FILE:3712; REG:49
# 9                                 FILE:1245; REG:256
#
#                                     example_messages
# 0  NTFS:\Windows\WinSxS\amd64_microsoft-windows-w...
# 1  System.Reflection.Context.nuspec File referenc...
# 2  NTFS:\Program Files\Microsoft Visual Studio\20...
# 3  Original URL: https://r.bing.com/rp/6zg86aHGTX...
# 4  NTFS:\Windows\WinSxS\amd64_userexperience-core...
# 5  [HKEY_LOCAL_MACHINE\Software\Classes\Interface...
# 6  [\DerivedData\VersionedIndex\10.0.22621.378 (W...
# 7  PE Type: Dynamic Link Library (DLL) Import has...
# 8  NTFS:\Program Files (x86)\Microsoft SDKs\Click...
# 9  [HKEY_LOCAL_MACHINE\Software\Microsoft\Windows...
